# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import skimage.morphology as mo

from skimage import io, color #Scikit-Image
from PIL import Image # Pillow
import cv2

import os
import random

import torch # Will work on using PyTorch here later
from torch.utils.data  import Dataset, DataLoader
from torchvision import transforms
import torchvision.transforms.functional as TF
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import matplotlib.pyplot as plt
import pandas as pd

# %%
validation_set_size = 0.2

# %%
class Muscle(Dataset):
    def __init__(self, split='train', transformX=None, transformY=None, test_size=0.2, val_size=0.1):
        """
        Custom dataset for neonatal muscle images and masks.

        Args:
            split (str): 'train', 'val', or 'test' to specify dataset partition.
            transformX (callable): Transform to apply to input image.
            transformY (callable): Transform to apply to mask.
            test_size (float): Proportion of the data used for test set.
            val_size (float): Proportion of the remaining training data used for validation.
        """
        self.transformX = transformX
        self.transformY = transformY
        self.split = split

        # Load full dataset
        self.pixel_file = pd.read_csv('/Users/taliacho/Downloads/Bryan-Ranger/local_data/abs_neonatal.csv')

        # First split: train+val and test
        train_val_data, self.test_data = train_test_split(
            self.pixel_file, test_size=test_size, random_state=5)

        # Second split: train and val from train_val
        self.train_data, self.validation_data = train_test_split(
            train_val_data, test_size=val_size, random_state=5)

    def __len__(self):
        if self.split == 'train':
            return len(self.train_data)
        elif self.split == 'val':
            return len(self.validation_data)
        else:
            return len(self.test_data)

    def __getitem__(self, index):
        base_path = '/Users/taliacho/Downloads/Bryan-Ranger/local_data/abs_neonatal_bw'

        if self.split == 'train':
            row = self.train_data.iloc[index]
        elif self.split == 'val':
            row = self.validation_data.iloc[index]
        else:
            row = self.test_data.iloc[index]

        img_name = os.path.join(base_path, row[1])
        mask_name = os.path.join(base_path, row[1].replace('.jpeg', '_m.jpeg'))

        imx = Image.open(img_name)
        imy = Image.open(mask_name).convert('L')

        if self.split == 'train':
            # Data augmentation for training
            if random.random() > 0.5:
                imx = TF.hflip(imx)
                imy = TF.hflip(imy)
            if random.random() > 0.5:
                imx = TF.vflip(imx)
                imy = TF.vflip(imy)
            if random.random() > 0.8:
                angle = random.choice([-90, -60, -45, -15, 0, 15, 30, 45, 60, 90])
                imx = TF.rotate(imx, angle)
                imy = TF.rotate(imy, angle)

        if self.transformX:
            imx = self.transformX(imx)
        if self.transformY:
            imy = self.transformY(imy)

        return {'image': imx, 'mask': imy}

# %%
# Init transform functions
tx_X = transforms.Compose([transforms.Resize((256, 256)),
                           transforms.ToTensor(),
                           transforms.Normalize((0.5,), (0.5,))])
tx_Y = transforms.Compose([transforms.Resize((256, 256)),
                           transforms.ToTensor(),  
                           # transforms.Normalize((0.5,), (0.5,))
                          ])

# %%
from torch.utils.data import DataLoader

# Create dataset instances for each split
train_data = Muscle(split='train', transformX=tx_X, transformY=tx_Y)
validation_data = Muscle(split='val', transformX=tx_X, transformY=tx_Y)
test_data = Muscle(split='test', transformX=tx_X, transformY=tx_Y)

# Create DataLoaders
train_loader = DataLoader(dataset=train_data, batch_size=8, shuffle=True, num_workers=0)
validation_loader = DataLoader(dataset=validation_data, batch_size=8, shuffle=False, num_workers=0)
test_loader = DataLoader(dataset=test_data, batch_size=8, shuffle=False, num_workers=0)

# Print number of samples
print("Number of training samples:", len(train_data))
print("Number of validation samples:", len(validation_data))
print("Number of test samples:", len(test_data))
# Out:
# Number of training samples: 675
# Number of validation samples: 75
# Number of test samples: 188

# %%
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# %%
# The following functions will return numpy array from the transformed tensors which were
# obtained from our train_loader. Plot them and see if they are intact
def im_converterX(tensor):
  image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy
                                              # as we will need original later
  image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
  print("image shape is ",image.shape)
  image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5)) # unnormalizing the image
                                              # this also outputs (28, 28, 3) which seems important for plt.imshow
  image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
  return image

def im_converterY(tensor):
  image = tensor.cpu().clone().detach().numpy()
  image = image.transpose(1,2,0)
  print("image shape is ",image.shape)
  image = image * np.array((1, 1, 1))
  image = image.clip(0, 1)
  return image

# %%
## Here we loop through our train_loader and see the images
fig = plt.figure(figsize = (15,6))

for ith_batch, sample_batched in enumerate(train_loader):
    print(ith_batch, sample_batched['image'].size(), sample_batched['mask'].size())

    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(sample_batched['image'][index]))
        ax = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(sample_batched['mask'][index]))
    break
# Out:
# 0 torch.Size([8, 1, 256, 256]) torch.Size([8, 1, 256, 256])
# image shape is  (256, 256, 1)
# image shape is  (256, 256, 1)
# image shape is  (256, 256, 1)
# image shape is  (256, 256, 1)
# /var/folders/4d/k9kg508s74x8f4h4b3sw0fsw0000gn/T/ipykernel_92553/3690571358.py:46: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   img_name = os.path.join(base_path, row[1])
# /var/folders/4d/k9kg508s74x8f4h4b3sw0fsw0000gn/T/ipykernel_92553/3690571358.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mask_name = os.path.join(base_path, row[1].replace('.jpeg', '_m.jpeg'))

# %%
class double_conv(nn.Module):
  '''(conv => BN => ReLU) * 2'''
  def __init__(self, in_ch, out_ch):
    super(double_conv, self).__init__()
    self.conv = nn.Sequential(
      nn.Conv2d(in_ch, out_ch, 3, padding=1),
      nn.BatchNorm2d(out_ch),
      nn.ReLU(inplace=True),
      nn.Conv2d(out_ch, out_ch, 3, padding=1),
      nn.BatchNorm2d(out_ch),
      nn.ReLU(inplace=True)
    )

  def forward(self, x):
    x = self.conv(x)
    return x

class inconv(nn.Module):
  def __init__(self, in_ch, out_ch):
    super(inconv, self).__init__()
    self.conv = double_conv(in_ch, out_ch)

  def forward(self, x):
    x = self.conv(x)
    return x

class down(nn.Module):
  def __init__(self, in_ch, out_ch):
    super(down, self).__init__()
    self.mpconv = nn.Sequential(
        nn.MaxPool2d(2),
        double_conv(in_ch, out_ch)
    )

  def forward(self, x):
    x = self.mpconv(x)
    return x


class up(nn.Module):
  def __init__(self, in_ch, out_ch, bilinear=True):
    super(up, self).__init__()
    self.up = nn.Upsample(
      scale_factor=2, mode='bilinear', align_corners=True)
    self.up = nn.ConvTranspose2d(in_ch // 2, in_ch // 2, kernel_size=2, stride=2)
    self.conv = double_conv(in_ch, out_ch)

  def forward(self, x1, x2):
    x1 = self.up(x1)
    diff1 = x2.shape[2]-x1.shape[2]
    diff2 = x2.shape[3]-x1.shape[3]
    x1 = F.pad(x1, pad=(diff1//2, diff1-diff1//2, diff2//2, diff2-diff2//2))
    x = torch.cat([x2, x1], dim=1)
    x = self.conv(x)
    return x


class outconv(nn.Module):
  def __init__(self, in_ch, out_ch):
    super(outconv, self).__init__()
    self.conv = nn.Conv2d(in_ch, out_ch, 1)

  def forward(self, x):
    x = self.conv(x)
    return x

# %%
class UNet(nn.Module):
  def __init__(self, n_channels, n_classes):
    super(UNet, self).__init__()
    self.inc = inconv(n_channels, 64)
    self.down1 = down(64, 128)
    self.down2 = down(128, 256)
    self.down3 = down(256, 512)
    self.down4 = down(512, 512)
    self.up1 = up(1024, 256, bilinear = False)
    self.up2 = up(512, 128, bilinear = False)
    self.up3 = up(256, 64, bilinear = False)
    self.up4 = up(128, 64, bilinear = False)
    self.outc = outconv(64, n_classes)
    self.dropout = torch.nn.Dropout2d(0.5)

  def forward(self, x):
    x = x.float()
    x1 = self.inc(x)
    x2 = self.down1(x1)
    x3 = self.down2(x2)
    x4 = self.down3(x3)
    x5 = self.down4(x4)
    x = self.up1(x5, x4)
    x = self.up2(x, x3)
    x = self.dropout(x)
    x = self.up3(x, x2)
    x = self.up4(x, x1)
    x = self.outc(x)
    return torch.sigmoid(x)

# %%
model = UNet(1, 1)
model.to(device)
print("Model Loaded to {device}")
# Out:
# Model Loaded to {device}

# %%
criterion = nn.BCELoss() # BCE = Binary Cross Entropy
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01) # lr = learning rate

# %%
# calculates similarity index between predicted and actual segmentation
def dice_index(y_pred, y_actual):
  smooth = 0.000001 # prevent division by 0
  size_of_batch = y_pred.size(0)

  p1 = y_pred.view(size_of_batch, -1)
  p2 = y_actual.view(size_of_batch, -1)

  intersection = (p1 * p2).sum()

  dice =  ((2.0 * intersection )+ smooth) / (p1.sum() + p2.sum() + smooth)
  #dice.requires_grad = True

  return dice

# calculate dice loss which will be later used in loss function calculation
def dice_loss(y_predict, y_train): ## to add in bce looss
  return 1 -(dice_index(y_predict, y_train))

# %%
epochs = 40 # number of iterations of the training dataset during the training process

train_running_loss_history = []
validation_running_loss_history = []

model.to(device)

for e in range(epochs):
  train_running_loss = 0.0
  validation_running_loss = 0.0
  model.train()
  for ith_batch, sample_batched in enumerate(train_loader):
    X_train = sample_batched['image'].to(device)
    y_train = sample_batched['mask'].to(device)
    optimizer.zero_grad()
    y_pred = model(X_train) # hayo: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same
    loss = 0.30 * dice_loss(y_pred, y_train) +  0.70 * criterion(y_pred, y_train)
    loss.backward()
    optimizer.step()
    if ith_batch % 5 == 0:
      print('Epoch: ', e + 1, 'Batch: ', ith_batch, 'Current Loss: ', loss.item())
    train_running_loss += loss.item()
  else:
    with torch.no_grad():
      model.eval()
      for ith_batch, sample_batched in enumerate(validation_loader):
        X_val = sample_batched['image'].to(device)
        y_val = sample_batched['mask'].to(device)
        y_out = model(X_val)
        out_val = (y_out + 0.5).int().float()
        val_loss = 0.3 * dice_loss(out_val, y_val)  + 0.7 * criterion(y_out, y_val)
        validation_running_loss += val_loss.item()
      print("================================================================================")
      print("Epoch {} completed".format(e + 1))

      train_epoch_loss = train_running_loss / len(train_loader)
      validation_epoch_loss = validation_running_loss / len(validation_loader)

      print("Average train loss is {}: ".format(train_epoch_loss))
      print("Average validation loss is {}".format(validation_epoch_loss))
      print("================================================================================")
      train_running_loss_history.append(train_epoch_loss)
      validation_running_loss_history.append(validation_epoch_loss)

  torch.mps.empty_cache() if device.type == 'mps' else torch.cuda.empty_cache()
# Out:
# /var/folders/4d/k9kg508s74x8f4h4b3sw0fsw0000gn/T/ipykernel_92553/3690571358.py:46: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   img_name = os.path.join(base_path, row[1])
# /var/folders/4d/k9kg508s74x8f4h4b3sw0fsw0000gn/T/ipykernel_92553/3690571358.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mask_name = os.path.join(base_path, row[1].replace('.jpeg', '_m.jpeg'))
# Epoch:  1 Batch:  0 Current Loss:  0.6414292454719543
# Epoch:  1 Batch:  5 Current Loss:  0.612967848777771
# Epoch:  1 Batch:  10 Current Loss:  0.5836546421051025
# Epoch:  1 Batch:  15 Current Loss:  0.5405638217926025
# Epoch:  1 Batch:  20 Current Loss:  0.46753010153770447
# Epoch:  1 Batch:  25 Current Loss:  0.3774018883705139
# Epoch:  1 Batch:  30 Current Loss:  0.41435760259628296
# Epoch:  1 Batch:  35 Current Loss:  0.4655693471431732
# Epoch:  1 Batch:  40 Current Loss:  0.40472421050071716
# Epoch:  1 Batch:  45 Current Loss:  0.487716406583786
# Epoch:  1 Batch:  50 Current Loss:  0.3728538751602173
# Epoch:  1 Batch:  55 Current Loss:  0.258392333984375
# Epoch:  1 Batch:  60 Current Loss:  0.2762462794780731
# Epoch:  1 Batch:  65 Current Loss:  0.25948935747146606
# Epoch:  1 Batch:  70 Current Loss:  0.333534836769104
# Epoch:  1 Batch:  75 Current Loss:  0.24997685849666595
# Epoch:  1 Batch:  80 Current Loss:  0.2014673948287964
# ================================================================================
# Epoch 1 completed
# Average train loss is 0.39295869154088636:
# Average validation loss is 0.3003822773694992
# ================================================================================
# Epoch:  2 Batch:  0 Current Loss:  0.26961952447891235
# Epoch:  2 Batch:  5 Current Loss:  0.2209095060825348
# Epoch:  2 Batch:  10 Current Loss:  0.1588456630706787
# Epoch:  2 Batch:  15 Current Loss:  0.2508240044116974
# Epoch:  2 Batch:  20 Current Loss:  0.27640780806541443
# Epoch:  2 Batch:  25 Current Loss:  0.3150467872619629
# Epoch:  2 Batch:  30 Current Loss:  0.26435786485671997
# Epoch:  2 Batch:  35 Current Loss:  0.35102468729019165
# Epoch:  2 Batch:  40 Current Loss:  0.25311094522476196
# Epoch:  2 Batch:  45 Current Loss:  0.2025047242641449
# Epoch:  2 Batch:  50 Current Loss:  0.2656934857368469
# Epoch:  2 Batch:  55 Current Loss:  0.2115366905927658
# Epoch:  2 Batch:  60 Current Loss:  0.18010500073432922
# Epoch:  2 Batch:  65 Current Loss:  0.3204400837421417
# Epoch:  2 Batch:  70 Current Loss:  0.2935110926628113
# Epoch:  2 Batch:  75 Current Loss:  0.29340794682502747
# Epoch:  2 Batch:  80 Current Loss:  0.31549590826034546
# ================================================================================
# Epoch 2 completed
# Average train loss is 0.2544455845566357:
# Average validation loss is 0.5130254864692688
# ================================================================================
# Epoch:  3 Batch:  0 Current Loss:  0.15559238195419312
# Epoch:  3 Batch:  5 Current Loss:  0.2724609076976776
# Epoch:  3 Batch:  10 Current Loss:  0.2565688490867615
# Epoch:  3 Batch:  15 Current Loss:  0.14598429203033447
# Epoch:  3 Batch:  20 Current Loss:  0.23522667586803436
# Epoch:  3 Batch:  25 Current Loss:  0.19440431892871857
# Epoch:  3 Batch:  30 Current Loss:  0.27898311614990234
# Epoch:  3 Batch:  35 Current Loss:  0.3605227768421173
# Epoch:  3 Batch:  40 Current Loss:  0.2309659719467163
# Epoch:  3 Batch:  45 Current Loss:  0.16554976999759674
# Epoch:  3 Batch:  50 Current Loss:  0.24021248519420624
# Epoch:  3 Batch:  55 Current Loss:  0.37904953956604004
# Epoch:  3 Batch:  60 Current Loss:  0.14730381965637207
# Epoch:  3 Batch:  65 Current Loss:  0.17684410512447357
# Epoch:  3 Batch:  70 Current Loss:  0.13097481429576874
# Epoch:  3 Batch:  75 Current Loss:  0.27537423372268677
# Epoch:  3 Batch:  80 Current Loss:  0.2719721496105194
# ================================================================================
# Epoch 3 completed
# Average train loss is 0.21993338535813725:
# Average validation loss is 0.7606628000736236
# ================================================================================
# Epoch:  4 Batch:  0 Current Loss:  0.2610803544521332
# Epoch:  4 Batch:  5 Current Loss:  0.21162517368793488
# Epoch:  4 Batch:  10 Current Loss:  0.148158997297287
# Epoch:  4 Batch:  15 Current Loss:  0.12082697451114655
# Epoch:  4 Batch:  20 Current Loss:  0.1542014181613922
# Epoch:  4 Batch:  25 Current Loss:  0.28966063261032104
# Epoch:  4 Batch:  30 Current Loss:  0.20528312027454376
# Epoch:  4 Batch:  35 Current Loss:  0.20053748786449432
# Epoch:  4 Batch:  40 Current Loss:  0.19333301484584808
# Epoch:  4 Batch:  45 Current Loss:  0.2517963945865631
# Epoch:  4 Batch:  50 Current Loss:  0.3614690899848938
# Epoch:  4 Batch:  55 Current Loss:  0.3149339556694031
# Epoch:  4 Batch:  60 Current Loss:  0.13613563776016235
# Epoch:  4 Batch:  65 Current Loss:  0.2901972830295563
# Epoch:  4 Batch:  70 Current Loss:  0.20259706676006317
# Epoch:  4 Batch:  75 Current Loss:  0.24903351068496704
# Epoch:  4 Batch:  80 Current Loss:  0.3141981363296509
# ================================================================================
# Epoch 4 completed
# Average train loss is 0.1927595244611011:
# Average validation loss is 0.5256436496973038
# ================================================================================
# Epoch:  5 Batch:  0 Current Loss:  0.2408873438835144
# Epoch:  5 Batch:  5 Current Loss:  0.13564592599868774
# Epoch:  5 Batch:  10 Current Loss:  0.19703349471092224
# Epoch:  5 Batch:  15 Current Loss:  0.177434042096138
# Epoch:  5 Batch:  20 Current Loss:  0.23121020197868347
# Epoch:  5 Batch:  25 Current Loss:  0.12181617319583893
# Epoch:  5 Batch:  30 Current Loss:  0.13250850141048431
# Epoch:  5 Batch:  35 Current Loss:  0.18495851755142212
# Epoch:  5 Batch:  40 Current Loss:  0.2216416299343109
# Epoch:  5 Batch:  45 Current Loss:  0.22181661427021027
# Epoch:  5 Batch:  50 Current Loss:  0.2082352489233017
# Epoch:  5 Batch:  55 Current Loss:  0.1534498929977417
# Epoch:  5 Batch:  60 Current Loss:  0.14291399717330933
# Epoch:  5 Batch:  65 Current Loss:  0.13263583183288574
# Epoch:  5 Batch:  70 Current Loss:  0.11759950965642929
# Epoch:  5 Batch:  75 Current Loss:  0.09750479459762573
# Epoch:  5 Batch:  80 Current Loss:  0.21444758772850037
# ================================================================================
# Epoch 5 completed
# Average train loss is 0.18623698590432897:
# Average validation loss is 0.4683130502700806
# ================================================================================
# Epoch:  6 Batch:  0 Current Loss:  0.3733373284339905
# Epoch:  6 Batch:  5 Current Loss:  0.18345963954925537
# Epoch:  6 Batch:  10 Current Loss:  0.24825617671012878
# Epoch:  6 Batch:  15 Current Loss:  0.1072661429643631
# Epoch:  6 Batch:  20 Current Loss:  0.16120612621307373
# Epoch:  6 Batch:  25 Current Loss:  0.17777906358242035
# Epoch:  6 Batch:  30 Current Loss:  0.15544188022613525
# Epoch:  6 Batch:  35 Current Loss:  0.19478347897529602
# Epoch:  6 Batch:  40 Current Loss:  0.1469762623310089
# Epoch:  6 Batch:  45 Current Loss:  0.12945905327796936
# Epoch:  6 Batch:  50 Current Loss:  0.20856279134750366
# Epoch:  6 Batch:  55 Current Loss:  0.10185308009386063
# Epoch:  6 Batch:  60 Current Loss:  0.3289772868156433
# Epoch:  6 Batch:  65 Current Loss:  0.31754833459854126
# Epoch:  6 Batch:  70 Current Loss:  0.1436498463153839
# Epoch:  6 Batch:  75 Current Loss:  0.2648311257362366
# Epoch:  6 Batch:  80 Current Loss:  0.11269775778055191
# ================================================================================
# Epoch 6 completed
# Average train loss is 0.17896734528681812:
# Average validation loss is 0.29339187443256376
# ================================================================================
# Epoch:  7 Batch:  0 Current Loss:  0.08828866481781006
# Epoch:  7 Batch:  5 Current Loss:  0.12055087089538574
# Epoch:  7 Batch:  10 Current Loss:  0.14747531712055206
# Epoch:  7 Batch:  15 Current Loss:  0.07935714721679688
# Epoch:  7 Batch:  20 Current Loss:  0.25550350546836853
# Epoch:  7 Batch:  25 Current Loss:  0.1780513972043991
# Epoch:  7 Batch:  30 Current Loss:  0.17508885264396667
# Epoch:  7 Batch:  35 Current Loss:  0.20051181316375732
# Epoch:  7 Batch:  40 Current Loss:  0.14286738634109497
# Epoch:  7 Batch:  45 Current Loss:  0.23256398737430573
# Epoch:  7 Batch:  50 Current Loss:  0.19692212343215942
# Epoch:  7 Batch:  55 Current Loss:  0.2544529438018799
# Epoch:  7 Batch:  60 Current Loss:  0.11101370304822922
# Epoch:  7 Batch:  65 Current Loss:  0.21819275617599487
# Epoch:  7 Batch:  70 Current Loss:  0.23856788873672485
# Epoch:  7 Batch:  75 Current Loss:  0.1890711635351181
# Epoch:  7 Batch:  80 Current Loss:  0.18527160584926605
# ================================================================================
# Epoch 7 completed
# Average train loss is 0.17841210233814575:
# Average validation loss is 0.2721048131585121
# ================================================================================
# Epoch:  8 Batch:  0 Current Loss:  0.14679887890815735
# Epoch:  8 Batch:  5 Current Loss:  0.13760294020175934
# Epoch:  8 Batch:  10 Current Loss:  0.16916301846504211
# Epoch:  8 Batch:  15 Current Loss:  0.14910295605659485
# Epoch:  8 Batch:  20 Current Loss:  0.18775933980941772
# Epoch:  8 Batch:  25 Current Loss:  0.21377348899841309
# Epoch:  8 Batch:  30 Current Loss:  0.11986657232046127
# Epoch:  8 Batch:  35 Current Loss:  0.13231240212917328
# Epoch:  8 Batch:  40 Current Loss:  0.1571715921163559
# Epoch:  8 Batch:  45 Current Loss:  0.19633053243160248
# Epoch:  8 Batch:  50 Current Loss:  0.16176281869411469
# Epoch:  8 Batch:  55 Current Loss:  0.1306827962398529
# Epoch:  8 Batch:  60 Current Loss:  0.21747015416622162
# Epoch:  8 Batch:  65 Current Loss:  0.10956431925296783
# Epoch:  8 Batch:  70 Current Loss:  0.15043532848358154
# Epoch:  8 Batch:  75 Current Loss:  0.11657872796058655
# Epoch:  8 Batch:  80 Current Loss:  0.1915101706981659
# ================================================================================
# Epoch 8 completed
# Average train loss is 0.15493668466806412:
# Average validation loss is 0.3358057975769043
# ================================================================================
# Epoch:  9 Batch:  0 Current Loss:  0.13023126125335693
# Epoch:  9 Batch:  5 Current Loss:  0.34046512842178345
# Epoch:  9 Batch:  10 Current Loss:  0.1306358277797699
# Epoch:  9 Batch:  15 Current Loss:  0.2666458785533905
# Epoch:  9 Batch:  20 Current Loss:  0.07562942802906036
# Epoch:  9 Batch:  25 Current Loss:  0.20586761832237244
# Epoch:  9 Batch:  30 Current Loss:  0.22558224201202393
# Epoch:  9 Batch:  35 Current Loss:  0.21553191542625427
# Epoch:  9 Batch:  40 Current Loss:  0.26543405652046204
# Epoch:  9 Batch:  45 Current Loss:  0.10023864358663559
# Epoch:  9 Batch:  50 Current Loss:  0.20244883000850677
# Epoch:  9 Batch:  55 Current Loss:  0.1272190362215042
# Epoch:  9 Batch:  60 Current Loss:  0.11132410913705826
# Epoch:  9 Batch:  65 Current Loss:  0.08352310210466385
# Epoch:  9 Batch:  70 Current Loss:  0.2196773737668991
# Epoch:  9 Batch:  75 Current Loss:  0.10104037076234818
# Epoch:  9 Batch:  80 Current Loss:  0.21266686916351318
# ================================================================================
# Epoch 9 completed
# Average train loss is 0.15774820372462273:
# Average validation loss is 0.11909048594534397
# ================================================================================
# Epoch:  10 Batch:  0 Current Loss:  0.11195006966590881
# Epoch:  10 Batch:  5 Current Loss:  0.23588420450687408
# Epoch:  10 Batch:  10 Current Loss:  0.08699780702590942
# Epoch:  10 Batch:  15 Current Loss:  0.17867812514305115
# Epoch:  10 Batch:  20 Current Loss:  0.11681213974952698
# Epoch:  10 Batch:  25 Current Loss:  0.20158694684505463
# Epoch:  10 Batch:  30 Current Loss:  0.16382935643196106
# Epoch:  10 Batch:  35 Current Loss:  0.10862123966217041
# Epoch:  10 Batch:  40 Current Loss:  0.18257535994052887
# Epoch:  10 Batch:  45 Current Loss:  0.16856998205184937
# Epoch:  10 Batch:  50 Current Loss:  0.11124339699745178
# Epoch:  10 Batch:  55 Current Loss:  0.07687821984291077
# Epoch:  10 Batch:  60 Current Loss:  0.12786521017551422
# Epoch:  10 Batch:  65 Current Loss:  0.08205430954694748
# Epoch:  10 Batch:  70 Current Loss:  0.2013973742723465
# Epoch:  10 Batch:  75 Current Loss:  0.30354490876197815
# Epoch:  10 Batch:  80 Current Loss:  0.09008542448282242
# ================================================================================
# Epoch 10 completed
# Average train loss is 0.15455069831188986:
# Average validation loss is 0.4148156732320786
# ================================================================================
# Epoch:  11 Batch:  0 Current Loss:  0.2160014659166336
# Epoch:  11 Batch:  5 Current Loss:  0.19905708730220795
# Epoch:  11 Batch:  10 Current Loss:  0.11746219545602798
# Epoch:  11 Batch:  15 Current Loss:  0.08440165966749191
# Epoch:  11 Batch:  20 Current Loss:  0.07183640450239182
# Epoch:  11 Batch:  25 Current Loss:  0.09443613886833191
# Epoch:  11 Batch:  30 Current Loss:  0.13594260811805725
# Epoch:  11 Batch:  35 Current Loss:  0.13470245897769928
# Epoch:  11 Batch:  40 Current Loss:  0.22362160682678223
# Epoch:  11 Batch:  45 Current Loss:  0.16042698919773102
# Epoch:  11 Batch:  50 Current Loss:  0.0929146260023117
# Epoch:  11 Batch:  55 Current Loss:  0.17388497292995453
# Epoch:  11 Batch:  60 Current Loss:  0.1313050538301468
# Epoch:  11 Batch:  65 Current Loss:  0.16079893708229065
# Epoch:  11 Batch:  70 Current Loss:  0.1304151862859726
# Epoch:  11 Batch:  75 Current Loss:  0.18083150684833527
# Epoch:  11 Batch:  80 Current Loss:  0.18960493803024292
# ================================================================================
# Epoch 11 completed
# Average train loss is 0.1543220780789852:
# Average validation loss is 0.37441534698009493
# ================================================================================
# Epoch:  12 Batch:  0 Current Loss:  0.11707247048616409
# Epoch:  12 Batch:  5 Current Loss:  0.13907134532928467
# Epoch:  12 Batch:  10 Current Loss:  0.20278926193714142
# Epoch:  12 Batch:  15 Current Loss:  0.10211198031902313
# Epoch:  12 Batch:  20 Current Loss:  0.05270002782344818
# Epoch:  12 Batch:  25 Current Loss:  0.18658562004566193
# Epoch:  12 Batch:  30 Current Loss:  0.12811264395713806
# Epoch:  12 Batch:  35 Current Loss:  0.1118398979306221
# Epoch:  12 Batch:  40 Current Loss:  0.07880575954914093
# Epoch:  12 Batch:  45 Current Loss:  0.2036687731742859
# Epoch:  12 Batch:  50 Current Loss:  0.2860247790813446
# Epoch:  12 Batch:  55 Current Loss:  0.18147961795330048
# Epoch:  12 Batch:  60 Current Loss:  0.15602527558803558
# Epoch:  12 Batch:  65 Current Loss:  0.16815035045146942
# Epoch:  12 Batch:  70 Current Loss:  0.136967271566391
# Epoch:  12 Batch:  75 Current Loss:  0.0917046070098877
# Epoch:  12 Batch:  80 Current Loss:  0.0869206041097641
# ================================================================================
# Epoch 12 completed
# Average train loss is 0.14328253120183945:
# Average validation loss is 0.7281139433383942
# ================================================================================
# Epoch:  13 Batch:  0 Current Loss:  0.07591605186462402
# Epoch:  13 Batch:  5 Current Loss:  0.1735723614692688
# Epoch:  13 Batch:  10 Current Loss:  0.053113169968128204
# Epoch:  13 Batch:  15 Current Loss:  0.06448590010404587
# Epoch:  13 Batch:  20 Current Loss:  0.10745765268802643
# Epoch:  13 Batch:  25 Current Loss:  0.08620735257863998
# Epoch:  13 Batch:  30 Current Loss:  0.17146536707878113
# Epoch:  13 Batch:  35 Current Loss:  0.12339834868907928
# Epoch:  13 Batch:  40 Current Loss:  0.10412445664405823
# Epoch:  13 Batch:  45 Current Loss:  0.3336338996887207
# Epoch:  13 Batch:  50 Current Loss:  0.19353339076042175
# Epoch:  13 Batch:  55 Current Loss:  0.14296692609786987
# Epoch:  13 Batch:  60 Current Loss:  0.13143248856067657
# Epoch:  13 Batch:  65 Current Loss:  0.2064402997493744
# Epoch:  13 Batch:  70 Current Loss:  0.1428869068622589
# Epoch:  13 Batch:  75 Current Loss:  0.26432564854621887
# Epoch:  13 Batch:  80 Current Loss:  0.40467914938926697
# ================================================================================
# Epoch 13 completed
# Average train loss is 0.14819454147535213:
# Average validation loss is 0.2368053451180458
# ================================================================================
# Epoch:  14 Batch:  0 Current Loss:  0.1291353404521942
# Epoch:  14 Batch:  5 Current Loss:  0.12494123727083206
# Epoch:  14 Batch:  10 Current Loss:  0.28243064880371094
# Epoch:  14 Batch:  15 Current Loss:  0.10630764812231064
# Epoch:  14 Batch:  20 Current Loss:  0.09380082786083221
# Epoch:  14 Batch:  25 Current Loss:  0.11839829385280609
# Epoch:  14 Batch:  30 Current Loss:  0.19221144914627075
# Epoch:  14 Batch:  35 Current Loss:  0.28517481684684753
# Epoch:  14 Batch:  40 Current Loss:  0.11987147480249405
# Epoch:  14 Batch:  45 Current Loss:  0.11648068577051163
# Epoch:  14 Batch:  50 Current Loss:  0.08423474431037903
# Epoch:  14 Batch:  55 Current Loss:  0.1293192207813263
# Epoch:  14 Batch:  60 Current Loss:  0.12627288699150085
# Epoch:  14 Batch:  65 Current Loss:  0.21346192061901093
# Epoch:  14 Batch:  70 Current Loss:  0.10262078046798706
# Epoch:  14 Batch:  75 Current Loss:  0.08363036811351776
# Epoch:  14 Batch:  80 Current Loss:  0.11370455473661423
# ================================================================================
# Epoch 14 completed
# Average train loss is 0.14554953141247526:
# Average validation loss is 0.11867940351366997
# ================================================================================
# Epoch:  15 Batch:  0 Current Loss:  0.07928816974163055
# Epoch:  15 Batch:  5 Current Loss:  0.08855769038200378
# Epoch:  15 Batch:  10 Current Loss:  0.11298912018537521
# Epoch:  15 Batch:  15 Current Loss:  0.1284056454896927
# Epoch:  15 Batch:  20 Current Loss:  0.13653817772865295
# Epoch:  15 Batch:  25 Current Loss:  0.21024444699287415
# Epoch:  15 Batch:  30 Current Loss:  0.16015318036079407
# Epoch:  15 Batch:  35 Current Loss:  0.11416450887918472
# Epoch:  15 Batch:  40 Current Loss:  0.12955904006958008
# Epoch:  15 Batch:  45 Current Loss:  0.08137006312608719
# Epoch:  15 Batch:  50 Current Loss:  0.15077243745326996
# Epoch:  15 Batch:  55 Current Loss:  0.07385849207639694
# Epoch:  15 Batch:  60 Current Loss:  0.05466078221797943
# Epoch:  15 Batch:  65 Current Loss:  0.11673612892627716
# Epoch:  15 Batch:  70 Current Loss:  0.12687796354293823
# Epoch:  15 Batch:  75 Current Loss:  0.17209398746490479
# Epoch:  15 Batch:  80 Current Loss:  0.20136825740337372
# ================================================================================
# Epoch 15 completed
# Average train loss is 0.1331175438621465:
# Average validation loss is 0.21343051120638848
# ================================================================================
# Epoch:  16 Batch:  0 Current Loss:  0.10890435427427292
# Epoch:  16 Batch:  5 Current Loss:  0.0925583764910698
# Epoch:  16 Batch:  10 Current Loss:  0.1289050579071045
# Epoch:  16 Batch:  15 Current Loss:  0.16573363542556763
# Epoch:  16 Batch:  20 Current Loss:  0.3232548236846924
# Epoch:  16 Batch:  25 Current Loss:  0.20823870599269867
# Epoch:  16 Batch:  30 Current Loss:  0.1889718472957611
# Epoch:  16 Batch:  35 Current Loss:  0.08823364973068237
# Epoch:  16 Batch:  40 Current Loss:  0.2666766941547394
# Epoch:  16 Batch:  45 Current Loss:  0.1451866328716278
# Epoch:  16 Batch:  50 Current Loss:  0.12734350562095642
# Epoch:  16 Batch:  55 Current Loss:  0.15971289575099945
# Epoch:  16 Batch:  60 Current Loss:  0.19249939918518066
# Epoch:  16 Batch:  65 Current Loss:  0.07444527000188828
# Epoch:  16 Batch:  70 Current Loss:  0.08978073298931122
# Epoch:  16 Batch:  75 Current Loss:  0.10203750431537628
# Epoch:  16 Batch:  80 Current Loss:  0.16439831256866455
# ================================================================================
# Epoch 16 completed
# Average train loss is 0.13930207639932632:
# Average validation loss is 0.10635640285909176
# ================================================================================
# Epoch:  17 Batch:  0 Current Loss:  0.052575595676898956
# Epoch:  17 Batch:  5 Current Loss:  0.18084952235221863
# Epoch:  17 Batch:  10 Current Loss:  0.09546991437673569
# Epoch:  17 Batch:  15 Current Loss:  0.09187369048595428
# Epoch:  17 Batch:  20 Current Loss:  0.08124452084302902
# Epoch:  17 Batch:  25 Current Loss:  0.12458576261997223
# Epoch:  17 Batch:  30 Current Loss:  0.22398924827575684
# Epoch:  17 Batch:  35 Current Loss:  0.11497429013252258
# Epoch:  17 Batch:  40 Current Loss:  0.11859208345413208
# Epoch:  17 Batch:  45 Current Loss:  0.1783657670021057
# Epoch:  17 Batch:  50 Current Loss:  0.21738776564598083
# Epoch:  17 Batch:  55 Current Loss:  0.06504788994789124
# Epoch:  17 Batch:  60 Current Loss:  0.18444527685642242
# Epoch:  17 Batch:  65 Current Loss:  0.12899717688560486
# Epoch:  17 Batch:  70 Current Loss:  0.11651106923818588
# Epoch:  17 Batch:  75 Current Loss:  0.2055695801973343
# Epoch:  17 Batch:  80 Current Loss:  0.12607185542583466
# ================================================================================
# Epoch 17 completed
# Average train loss is 0.13780834617860177:
# Average validation loss is 0.5968481212854385
# ================================================================================
# Epoch:  18 Batch:  0 Current Loss:  0.10072379559278488
# Epoch:  18 Batch:  5 Current Loss:  0.12408030033111572
# Epoch:  18 Batch:  10 Current Loss:  0.11735405772924423
# Epoch:  18 Batch:  15 Current Loss:  0.2525823712348938
# Epoch:  18 Batch:  20 Current Loss:  0.13010230660438538
# Epoch:  18 Batch:  25 Current Loss:  0.14766742289066315
# Epoch:  18 Batch:  30 Current Loss:  0.07329531759023666
# Epoch:  18 Batch:  35 Current Loss:  0.17369557917118073
# Epoch:  18 Batch:  40 Current Loss:  0.11030410975217819
# Epoch:  18 Batch:  45 Current Loss:  0.0645660012960434
# Epoch:  18 Batch:  50 Current Loss:  0.06480701267719269
# Epoch:  18 Batch:  55 Current Loss:  0.2959006130695343
# Epoch:  18 Batch:  60 Current Loss:  0.17509274184703827
# Epoch:  18 Batch:  65 Current Loss:  0.17038148641586304
# Epoch:  18 Batch:  70 Current Loss:  0.11253541707992554
# Epoch:  18 Batch:  75 Current Loss:  0.2409527748823166
# Epoch:  18 Batch:  80 Current Loss:  0.07217913866043091
# ================================================================================
# Epoch 18 completed
# Average train loss is 0.13412209902616107:
# Average validation loss is 0.14208536222577095
# ================================================================================
# Epoch:  19 Batch:  0 Current Loss:  0.13240942358970642
# Epoch:  19 Batch:  5 Current Loss:  0.16485388576984406
# Epoch:  19 Batch:  10 Current Loss:  0.06227828562259674
# Epoch:  19 Batch:  15 Current Loss:  0.4158153533935547
# Epoch:  19 Batch:  20 Current Loss:  0.13227365911006927
# Epoch:  19 Batch:  25 Current Loss:  0.10414403676986694
# Epoch:  19 Batch:  30 Current Loss:  0.0986475795507431
# Epoch:  19 Batch:  35 Current Loss:  0.0893346443772316
# Epoch:  19 Batch:  40 Current Loss:  0.09013928472995758
# Epoch:  19 Batch:  45 Current Loss:  0.213869109749794
# Epoch:  19 Batch:  50 Current Loss:  0.0923880934715271
# Epoch:  19 Batch:  55 Current Loss:  0.14341984689235687
# Epoch:  19 Batch:  60 Current Loss:  0.09874285757541656
# Epoch:  19 Batch:  65 Current Loss:  0.18945905566215515
# Epoch:  19 Batch:  70 Current Loss:  0.1029624342918396
# Epoch:  19 Batch:  75 Current Loss:  0.07801826298236847
# Epoch:  19 Batch:  80 Current Loss:  0.11036469042301178
# ================================================================================
# Epoch 19 completed
# Average train loss is 0.1373649076503866:
# Average validation loss is 0.2473618730902672
# ================================================================================
# Epoch:  20 Batch:  0 Current Loss:  0.09164708107709885
# Epoch:  20 Batch:  5 Current Loss:  0.1616940200328827
# Epoch:  20 Batch:  10 Current Loss:  0.1158996969461441
# Epoch:  20 Batch:  15 Current Loss:  0.12143261730670929
# Epoch:  20 Batch:  20 Current Loss:  0.10174235701560974
# Epoch:  20 Batch:  25 Current Loss:  0.05929043889045715
# Epoch:  20 Batch:  30 Current Loss:  0.30965062975883484
# Epoch:  20 Batch:  35 Current Loss:  0.08065278083086014
# Epoch:  20 Batch:  40 Current Loss:  0.09391840547323227
# Epoch:  20 Batch:  45 Current Loss:  0.13624195754528046
# Epoch:  20 Batch:  50 Current Loss:  0.2247399091720581
# Epoch:  20 Batch:  55 Current Loss:  0.1779327541589737
# Epoch:  20 Batch:  60 Current Loss:  0.11062260717153549
# Epoch:  20 Batch:  65 Current Loss:  0.11336202174425125
# Epoch:  20 Batch:  70 Current Loss:  0.22804749011993408
# Epoch:  20 Batch:  75 Current Loss:  0.11966986954212189
# Epoch:  20 Batch:  80 Current Loss:  0.07718919217586517
# ================================================================================
# Epoch 20 completed
# Average train loss is 0.1292629613157581:
# Average validation loss is 0.10369550921022892
# ================================================================================
# Epoch:  21 Batch:  0 Current Loss:  0.12442415952682495
# Epoch:  21 Batch:  5 Current Loss:  0.18520180881023407
# Epoch:  21 Batch:  10 Current Loss:  0.15428462624549866
# Epoch:  21 Batch:  15 Current Loss:  0.05786466225981712
# Epoch:  21 Batch:  20 Current Loss:  0.07893145084381104
# Epoch:  21 Batch:  25 Current Loss:  0.15466676652431488
# Epoch:  21 Batch:  30 Current Loss:  0.10450626909732819
# Epoch:  21 Batch:  35 Current Loss:  0.07214107364416122
# Epoch:  21 Batch:  40 Current Loss:  0.06635195016860962
# Epoch:  21 Batch:  45 Current Loss:  0.10038777440786362
# Epoch:  21 Batch:  50 Current Loss:  0.09022456407546997
# Epoch:  21 Batch:  55 Current Loss:  0.1439417004585266
# Epoch:  21 Batch:  60 Current Loss:  0.1822042465209961
# Epoch:  21 Batch:  65 Current Loss:  0.19685550034046173
# Epoch:  21 Batch:  70 Current Loss:  0.11595462262630463
# Epoch:  21 Batch:  75 Current Loss:  0.09189766645431519
# Epoch:  21 Batch:  80 Current Loss:  0.15054376423358917
# ================================================================================
# Epoch 21 completed
# Average train loss is 0.12690332159399986:
# Average validation loss is 0.10702700428664684
# ================================================================================
# Epoch:  22 Batch:  0 Current Loss:  0.12712490558624268
# Epoch:  22 Batch:  5 Current Loss:  0.11395878344774246
# Epoch:  22 Batch:  10 Current Loss:  0.13513076305389404
# Epoch:  22 Batch:  15 Current Loss:  0.09167178720235825
# Epoch:  22 Batch:  20 Current Loss:  0.11275220662355423
# Epoch:  22 Batch:  25 Current Loss:  0.16425123810768127
# Epoch:  22 Batch:  30 Current Loss:  0.045636262744665146
# Epoch:  22 Batch:  35 Current Loss:  0.07521459460258484
# Epoch:  22 Batch:  40 Current Loss:  0.13073605298995972
# Epoch:  22 Batch:  45 Current Loss:  0.17685064673423767
# Epoch:  22 Batch:  50 Current Loss:  0.1282784342765808
# Epoch:  22 Batch:  55 Current Loss:  0.11175893247127533
# Epoch:  22 Batch:  60 Current Loss:  0.12743626534938812
# Epoch:  22 Batch:  65 Current Loss:  0.0668010413646698
# Epoch:  22 Batch:  70 Current Loss:  0.0804506316781044
# Epoch:  22 Batch:  75 Current Loss:  0.14905545115470886
# Epoch:  22 Batch:  80 Current Loss:  0.06069066375494003
# ================================================================================
# Epoch 22 completed
# Average train loss is 0.11822925508022308:
# Average validation loss is 0.11219209805130959
# ================================================================================
# Epoch:  23 Batch:  0 Current Loss:  0.14388780295848846
# Epoch:  23 Batch:  5 Current Loss:  0.19948041439056396
# Epoch:  23 Batch:  10 Current Loss:  0.04458169639110565
# Epoch:  23 Batch:  15 Current Loss:  0.1992211639881134
# Epoch:  23 Batch:  20 Current Loss:  0.0868121087551117
# Epoch:  23 Batch:  25 Current Loss:  0.11166322976350784
# Epoch:  23 Batch:  30 Current Loss:  0.12544362246990204
# Epoch:  23 Batch:  35 Current Loss:  0.17848114669322968
# Epoch:  23 Batch:  40 Current Loss:  0.21276640892028809
# Epoch:  23 Batch:  45 Current Loss:  0.12232904881238937
# Epoch:  23 Batch:  50 Current Loss:  0.18160131573677063
# Epoch:  23 Batch:  55 Current Loss:  0.1013449877500534
# Epoch:  23 Batch:  60 Current Loss:  0.11636895686388016
# Epoch:  23 Batch:  65 Current Loss:  0.07858637720346451
# Epoch:  23 Batch:  70 Current Loss:  0.09019649028778076
# Epoch:  23 Batch:  75 Current Loss:  0.07735399901866913
# Epoch:  23 Batch:  80 Current Loss:  0.06459904462099075
# ================================================================================
# Epoch 23 completed
# Average train loss is 0.11969916097381536:
# Average validation loss is 0.11803681217133999
# ================================================================================
# Epoch:  24 Batch:  0 Current Loss:  0.057205282151699066
# Epoch:  24 Batch:  5 Current Loss:  0.14144891500473022
# Epoch:  24 Batch:  10 Current Loss:  0.06275247037410736
# Epoch:  24 Batch:  15 Current Loss:  0.0876694992184639
# Epoch:  24 Batch:  20 Current Loss:  0.09303442388772964
# Epoch:  24 Batch:  25 Current Loss:  0.06402181833982468
# Epoch:  24 Batch:  30 Current Loss:  0.1168527603149414
# Epoch:  24 Batch:  35 Current Loss:  0.10086559504270554
# Epoch:  24 Batch:  40 Current Loss:  0.07809947431087494
# Epoch:  24 Batch:  45 Current Loss:  0.13253504037857056
# Epoch:  24 Batch:  50 Current Loss:  0.08602815866470337
# Epoch:  24 Batch:  55 Current Loss:  0.04762629419565201
# Epoch:  24 Batch:  60 Current Loss:  0.07282975316047668
# Epoch:  24 Batch:  65 Current Loss:  0.06674796342849731
# Epoch:  24 Batch:  70 Current Loss:  0.09266382455825806
# Epoch:  24 Batch:  75 Current Loss:  0.05542561411857605
# Epoch:  24 Batch:  80 Current Loss:  0.11140526831150055
# ================================================================================
# Epoch 24 completed
# Average train loss is 0.1280820870662437:
# Average validation loss is 0.17052651420235634
# ================================================================================
# Epoch:  25 Batch:  0 Current Loss:  0.25924593210220337
# Epoch:  25 Batch:  5 Current Loss:  0.07725435495376587
# Epoch:  25 Batch:  10 Current Loss:  0.11001117527484894
# Epoch:  25 Batch:  15 Current Loss:  0.10380728542804718
# Epoch:  25 Batch:  20 Current Loss:  0.09691199660301208
# Epoch:  25 Batch:  25 Current Loss:  0.05771660432219505
# Epoch:  25 Batch:  30 Current Loss:  0.23789294064044952
# Epoch:  25 Batch:  35 Current Loss:  0.06176631525158882
# Epoch:  25 Batch:  40 Current Loss:  0.1443641483783722
# Epoch:  25 Batch:  45 Current Loss:  0.09181486815214157
# Epoch:  25 Batch:  50 Current Loss:  0.15592072904109955
# Epoch:  25 Batch:  55 Current Loss:  0.07170780748128891
# Epoch:  25 Batch:  60 Current Loss:  0.21661940217018127
# Epoch:  25 Batch:  65 Current Loss:  0.04509064182639122
# Epoch:  25 Batch:  70 Current Loss:  0.1811474859714508
# Epoch:  25 Batch:  75 Current Loss:  0.07680043578147888
# Epoch:  25 Batch:  80 Current Loss:  0.10995335876941681
# ================================================================================
# Epoch 25 completed
# Average train loss is 0.12383137113031219:
# Average validation loss is 0.24443442970514298
# ================================================================================
# Epoch:  26 Batch:  0 Current Loss:  0.08539273589849472
# Epoch:  26 Batch:  5 Current Loss:  0.058212555944919586
# Epoch:  26 Batch:  10 Current Loss:  0.11104345321655273
# Epoch:  26 Batch:  15 Current Loss:  0.074446901679039
# Epoch:  26 Batch:  20 Current Loss:  0.11869323253631592
# Epoch:  26 Batch:  25 Current Loss:  0.0567682683467865
# Epoch:  26 Batch:  30 Current Loss:  0.09614894539117813
# Epoch:  26 Batch:  35 Current Loss:  0.08094292879104614
# Epoch:  26 Batch:  40 Current Loss:  0.0903400406241417
# Epoch:  26 Batch:  45 Current Loss:  0.21623273193836212
# Epoch:  26 Batch:  50 Current Loss:  0.099319227039814
# Epoch:  26 Batch:  55 Current Loss:  0.19869667291641235
# Epoch:  26 Batch:  60 Current Loss:  0.10327126085758209
# Epoch:  26 Batch:  65 Current Loss:  0.10632620751857758
# Epoch:  26 Batch:  70 Current Loss:  0.27494898438453674
# Epoch:  26 Batch:  75 Current Loss:  0.10484206676483154
# Epoch:  26 Batch:  80 Current Loss:  0.08708207309246063
# ================================================================================
# Epoch 26 completed
# Average train loss is 0.12063910912941483:
# Average validation loss is 0.17335591614246368
# ================================================================================
# Epoch:  27 Batch:  0 Current Loss:  0.14277467131614685
# Epoch:  27 Batch:  5 Current Loss:  0.1514481008052826
# Epoch:  27 Batch:  10 Current Loss:  0.1871778964996338
# Epoch:  27 Batch:  15 Current Loss:  0.10138101130723953
# Epoch:  27 Batch:  20 Current Loss:  0.12356153875589371
# Epoch:  27 Batch:  25 Current Loss:  0.07305951416492462
# Epoch:  27 Batch:  30 Current Loss:  0.07099829614162445
# Epoch:  27 Batch:  35 Current Loss:  0.12269014120101929
# Epoch:  27 Batch:  40 Current Loss:  0.1972118467092514
# Epoch:  27 Batch:  45 Current Loss:  0.10921011120080948
# Epoch:  27 Batch:  50 Current Loss:  0.09049862623214722
# Epoch:  27 Batch:  55 Current Loss:  0.08418885618448257
# Epoch:  27 Batch:  60 Current Loss:  0.08975578844547272
# Epoch:  27 Batch:  65 Current Loss:  0.08010226488113403
# Epoch:  27 Batch:  70 Current Loss:  0.06071759760379791
# Epoch:  27 Batch:  75 Current Loss:  0.06753049790859222
# Epoch:  27 Batch:  80 Current Loss:  0.09916727244853973
# ================================================================================
# Epoch 27 completed
# Average train loss is 0.1116045260692344:
# Average validation loss is 0.16853631064295768
# ================================================================================
# Epoch:  28 Batch:  0 Current Loss:  0.11044910550117493
# Epoch:  28 Batch:  5 Current Loss:  0.16517877578735352
# Epoch:  28 Batch:  10 Current Loss:  0.0946950763463974
# Epoch:  28 Batch:  15 Current Loss:  0.09980171918869019
# Epoch:  28 Batch:  20 Current Loss:  0.12245437502861023
# Epoch:  28 Batch:  25 Current Loss:  0.05942735821008682
# Epoch:  28 Batch:  30 Current Loss:  0.10448727011680603
# Epoch:  28 Batch:  35 Current Loss:  0.17418047785758972
# Epoch:  28 Batch:  40 Current Loss:  0.07932340353727341
# Epoch:  28 Batch:  45 Current Loss:  0.07139387726783752
# Epoch:  28 Batch:  50 Current Loss:  0.08027242124080658
# Epoch:  28 Batch:  55 Current Loss:  0.13044477999210358
# Epoch:  28 Batch:  60 Current Loss:  0.10301963239908218
# Epoch:  28 Batch:  65 Current Loss:  0.07727599143981934
# Epoch:  28 Batch:  70 Current Loss:  0.06149914115667343
# Epoch:  28 Batch:  75 Current Loss:  0.10411770641803741
# Epoch:  28 Batch:  80 Current Loss:  0.055004753172397614
# ================================================================================
# Epoch 28 completed
# Average train loss is 0.11405058148152689:
# Average validation loss is 0.11190643385052682
# ================================================================================
# Epoch:  29 Batch:  0 Current Loss:  0.10662072151899338
# Epoch:  29 Batch:  5 Current Loss:  0.13612361252307892
# Epoch:  29 Batch:  10 Current Loss:  0.0738164633512497
# Epoch:  29 Batch:  15 Current Loss:  0.11600810289382935
# Epoch:  29 Batch:  20 Current Loss:  0.1701216697692871
# Epoch:  29 Batch:  25 Current Loss:  0.16251449286937714
# Epoch:  29 Batch:  30 Current Loss:  0.15670523047447205
# Epoch:  29 Batch:  35 Current Loss:  0.06862065196037292
# Epoch:  29 Batch:  40 Current Loss:  0.1754075437784195
# Epoch:  29 Batch:  45 Current Loss:  0.09360486268997192
# Epoch:  29 Batch:  50 Current Loss:  0.11089209467172623
# Epoch:  29 Batch:  55 Current Loss:  0.11786362528800964
# Epoch:  29 Batch:  60 Current Loss:  0.11177396774291992
# Epoch:  29 Batch:  65 Current Loss:  0.13443681597709656
# Epoch:  29 Batch:  70 Current Loss:  0.16782709956169128
# Epoch:  29 Batch:  75 Current Loss:  0.2897251844406128
# Epoch:  29 Batch:  80 Current Loss:  0.18273115158081055
# ================================================================================
# Epoch 29 completed
# Average train loss is 0.1089951753616333:
# Average validation loss is 0.09176921583712101
# ================================================================================
# Epoch:  30 Batch:  0 Current Loss:  0.04998160898685455
# Epoch:  30 Batch:  5 Current Loss:  0.08983951807022095
# Epoch:  30 Batch:  10 Current Loss:  0.05191851407289505
# Epoch:  30 Batch:  15 Current Loss:  0.132805734872818
# Epoch:  30 Batch:  20 Current Loss:  0.063233382999897
# Epoch:  30 Batch:  25 Current Loss:  0.04181379824876785
# Epoch:  30 Batch:  30 Current Loss:  0.07480243593454361
# Epoch:  30 Batch:  35 Current Loss:  0.14374297857284546
# Epoch:  30 Batch:  40 Current Loss:  0.11768431216478348
# Epoch:  30 Batch:  45 Current Loss:  0.11507552862167358
# Epoch:  30 Batch:  50 Current Loss:  0.12536203861236572
# Epoch:  30 Batch:  55 Current Loss:  0.11842884868383408
# Epoch:  30 Batch:  60 Current Loss:  0.11471196264028549
# Epoch:  30 Batch:  65 Current Loss:  0.223163440823555
# Epoch:  30 Batch:  70 Current Loss:  0.0657525509595871
# Epoch:  30 Batch:  75 Current Loss:  0.15415526926517487
# Epoch:  30 Batch:  80 Current Loss:  0.09386660903692245
# ================================================================================
# Epoch 30 completed
# Average train loss is 0.11071604393860873:
# Average validation loss is 0.131121975928545
# ================================================================================
# Epoch:  31 Batch:  0 Current Loss:  0.15584322810173035
# Epoch:  31 Batch:  5 Current Loss:  0.07221820950508118
# Epoch:  31 Batch:  10 Current Loss:  0.06960886716842651
# Epoch:  31 Batch:  15 Current Loss:  0.04884735494852066
# Epoch:  31 Batch:  20 Current Loss:  0.04855167865753174
# Epoch:  31 Batch:  25 Current Loss:  0.08438263833522797
# Epoch:  31 Batch:  30 Current Loss:  0.11697185784578323
# Epoch:  31 Batch:  35 Current Loss:  0.13249342143535614
# Epoch:  31 Batch:  40 Current Loss:  0.1965712308883667
# Epoch:  31 Batch:  45 Current Loss:  0.1079699695110321
# Epoch:  31 Batch:  50 Current Loss:  0.05424720048904419
# Epoch:  31 Batch:  55 Current Loss:  0.06399781256914139
# Epoch:  31 Batch:  60 Current Loss:  0.12360624969005585
# Epoch:  31 Batch:  65 Current Loss:  0.16168278455734253
# Epoch:  31 Batch:  70 Current Loss:  0.07769902050495148
# Epoch:  31 Batch:  75 Current Loss:  0.2156001478433609
# Epoch:  31 Batch:  80 Current Loss:  0.06225521117448807
# ================================================================================
# Epoch 31 completed
# Average train loss is 0.10941819618729984:
# Average validation loss is 0.12235091030597686
# ================================================================================
# Epoch:  32 Batch:  0 Current Loss:  0.04661940783262253
# Epoch:  32 Batch:  5 Current Loss:  0.05682944506406784
# Epoch:  32 Batch:  10 Current Loss:  0.07937206327915192
# Epoch:  32 Batch:  15 Current Loss:  0.1046871691942215
# Epoch:  32 Batch:  20 Current Loss:  0.10026786476373672
# Epoch:  32 Batch:  25 Current Loss:  0.13668015599250793
# Epoch:  32 Batch:  30 Current Loss:  0.05731201171875
# Epoch:  32 Batch:  35 Current Loss:  0.13621830940246582
# Epoch:  32 Batch:  40 Current Loss:  0.12986907362937927
# Epoch:  32 Batch:  45 Current Loss:  0.17897504568099976
# Epoch:  32 Batch:  50 Current Loss:  0.09559346735477448
# Epoch:  32 Batch:  55 Current Loss:  0.04665668308734894
# Epoch:  32 Batch:  60 Current Loss:  0.20215529203414917
# Epoch:  32 Batch:  65 Current Loss:  0.11539393663406372
# Epoch:  32 Batch:  70 Current Loss:  0.2454812377691269
# Epoch:  32 Batch:  75 Current Loss:  0.05770150572061539
# Epoch:  32 Batch:  80 Current Loss:  0.12090357393026352
# ================================================================================
# Epoch 32 completed
# Average train loss is 0.11478462263065226:
# Average validation loss is 0.10546106435358524
# ================================================================================
# Epoch:  33 Batch:  0 Current Loss:  0.05757342278957367
# Epoch:  33 Batch:  5 Current Loss:  0.05734369531273842
# Epoch:  33 Batch:  10 Current Loss:  0.12690405547618866
# Epoch:  33 Batch:  15 Current Loss:  0.04784263297915459
# Epoch:  33 Batch:  20 Current Loss:  0.058882493525743484
# Epoch:  33 Batch:  25 Current Loss:  0.06017085909843445
# Epoch:  33 Batch:  30 Current Loss:  0.1334570050239563
# Epoch:  33 Batch:  35 Current Loss:  0.11308262497186661
# Epoch:  33 Batch:  40 Current Loss:  0.14862412214279175
# Epoch:  33 Batch:  45 Current Loss:  0.12122637033462524
# Epoch:  33 Batch:  50 Current Loss:  0.1477796584367752
# Epoch:  33 Batch:  55 Current Loss:  0.05524006858468056
# Epoch:  33 Batch:  60 Current Loss:  0.10692939162254333
# Epoch:  33 Batch:  65 Current Loss:  0.11064605414867401
# Epoch:  33 Batch:  70 Current Loss:  0.24158331751823425
# Epoch:  33 Batch:  75 Current Loss:  0.1027984470129013
# Epoch:  33 Batch:  80 Current Loss:  0.1512877345085144
# ================================================================================
# Epoch 33 completed
# Average train loss is 0.10554956697365817:
# Average validation loss is 0.08997380249202251
# ================================================================================
# Epoch:  34 Batch:  0 Current Loss:  0.1560991108417511
# Epoch:  34 Batch:  5 Current Loss:  0.17577145993709564
# Epoch:  34 Batch:  10 Current Loss:  0.087522491812706
# Epoch:  34 Batch:  15 Current Loss:  0.05497654527425766
# Epoch:  34 Batch:  20 Current Loss:  0.05573706328868866
# Epoch:  34 Batch:  25 Current Loss:  0.051960721611976624
# Epoch:  34 Batch:  30 Current Loss:  0.07743047177791595
# Epoch:  34 Batch:  35 Current Loss:  0.16236719489097595
# Epoch:  34 Batch:  40 Current Loss:  0.10804757475852966
# Epoch:  34 Batch:  45 Current Loss:  0.07525387406349182
# Epoch:  34 Batch:  50 Current Loss:  0.11045931279659271
# Epoch:  34 Batch:  55 Current Loss:  0.04409748315811157
# Epoch:  34 Batch:  60 Current Loss:  0.1025393009185791
# Epoch:  34 Batch:  65 Current Loss:  0.08838338404893875
# Epoch:  34 Batch:  70 Current Loss:  0.0823519229888916
# Epoch:  34 Batch:  75 Current Loss:  0.07463191449642181
# Epoch:  34 Batch:  80 Current Loss:  0.07965659350156784
# ================================================================================
# Epoch 34 completed
# Average train loss is 0.11142943019376081:
# Average validation loss is 0.10952941477298736
# ================================================================================
# Epoch:  35 Batch:  0 Current Loss:  0.10250897705554962
# Epoch:  35 Batch:  5 Current Loss:  0.07328975945711136
# Epoch:  35 Batch:  10 Current Loss:  0.10065421462059021
# Epoch:  35 Batch:  15 Current Loss:  0.13211269676685333
# Epoch:  35 Batch:  20 Current Loss:  0.2734353840351105
# Epoch:  35 Batch:  25 Current Loss:  0.0685797929763794
# Epoch:  35 Batch:  30 Current Loss:  0.08000066876411438
# Epoch:  35 Batch:  35 Current Loss:  0.10226999223232269
# Epoch:  35 Batch:  40 Current Loss:  0.053738195449113846
# Epoch:  35 Batch:  45 Current Loss:  0.05360080674290657
# Epoch:  35 Batch:  50 Current Loss:  0.11161674559116364
# Epoch:  35 Batch:  55 Current Loss:  0.14252625405788422
# Epoch:  35 Batch:  60 Current Loss:  0.19288146495819092
# Epoch:  35 Batch:  65 Current Loss:  0.06521961838006973
# Epoch:  35 Batch:  70 Current Loss:  0.08921930938959122
# Epoch:  35 Batch:  75 Current Loss:  0.0983598604798317
# Epoch:  35 Batch:  80 Current Loss:  0.22444790601730347
# ================================================================================
# Epoch 35 completed
# Average train loss is 0.10716377676409834:
# Average validation loss is 0.12513063177466394
# ================================================================================
# Epoch:  36 Batch:  0 Current Loss:  0.0994216725230217
# Epoch:  36 Batch:  5 Current Loss:  0.1141049712896347
# Epoch:  36 Batch:  10 Current Loss:  0.0797782838344574
# Epoch:  36 Batch:  15 Current Loss:  0.1755828559398651
# Epoch:  36 Batch:  20 Current Loss:  0.11920119822025299
# Epoch:  36 Batch:  25 Current Loss:  0.1369045227766037
# Epoch:  36 Batch:  30 Current Loss:  0.05711255595088005
# Epoch:  36 Batch:  35 Current Loss:  0.07480131089687347
# Epoch:  36 Batch:  40 Current Loss:  0.06206056848168373
# Epoch:  36 Batch:  45 Current Loss:  0.09662051498889923
# Epoch:  36 Batch:  50 Current Loss:  0.0869571715593338
# Epoch:  36 Batch:  55 Current Loss:  0.15859609842300415
# Epoch:  36 Batch:  60 Current Loss:  0.06089842692017555
# Epoch:  36 Batch:  65 Current Loss:  0.09335382282733917
# Epoch:  36 Batch:  70 Current Loss:  0.09310442954301834
# Epoch:  36 Batch:  75 Current Loss:  0.06028786301612854
# Epoch:  36 Batch:  80 Current Loss:  0.06270430237054825
# ================================================================================
# Epoch 36 completed
# Average train loss is 0.10071948477450539:
# Average validation loss is 0.13712827097624541
# ================================================================================
# Epoch:  37 Batch:  0 Current Loss:  0.06477737426757812
# Epoch:  37 Batch:  5 Current Loss:  0.17650336027145386
# Epoch:  37 Batch:  10 Current Loss:  0.051204897463321686
# Epoch:  37 Batch:  15 Current Loss:  0.05527766793966293
# Epoch:  37 Batch:  20 Current Loss:  0.1720276027917862
# Epoch:  37 Batch:  25 Current Loss:  0.17009656131267548
# Epoch:  37 Batch:  30 Current Loss:  0.0534818209707737
# Epoch:  37 Batch:  35 Current Loss:  0.07480405271053314
# Epoch:  37 Batch:  40 Current Loss:  0.05403582751750946
# Epoch:  37 Batch:  45 Current Loss:  0.2317368984222412
# Epoch:  37 Batch:  50 Current Loss:  0.09076333045959473
# Epoch:  37 Batch:  55 Current Loss:  0.10142982006072998
# Epoch:  37 Batch:  60 Current Loss:  0.06745488941669464
# Epoch:  37 Batch:  65 Current Loss:  0.07614404708147049
# Epoch:  37 Batch:  70 Current Loss:  0.27787458896636963
# Epoch:  37 Batch:  75 Current Loss:  0.09112805128097534
# Epoch:  37 Batch:  80 Current Loss:  0.07942663133144379
# ================================================================================
# Epoch 37 completed
# Average train loss is 0.10614416542298653:
# Average validation loss is 0.427507272362709
# ================================================================================
# Epoch:  38 Batch:  0 Current Loss:  0.09137281030416489
# Epoch:  38 Batch:  5 Current Loss:  0.05109839513897896
# Epoch:  38 Batch:  10 Current Loss:  0.08937928080558777
# Epoch:  38 Batch:  15 Current Loss:  0.06798475980758667
# Epoch:  38 Batch:  20 Current Loss:  0.062450964003801346
# Epoch:  38 Batch:  25 Current Loss:  0.05168386548757553
# Epoch:  38 Batch:  30 Current Loss:  0.14253264665603638
# Epoch:  38 Batch:  35 Current Loss:  0.15498897433280945
# Epoch:  38 Batch:  40 Current Loss:  0.12582604587078094
# Epoch:  38 Batch:  45 Current Loss:  0.11587045341730118
# Epoch:  38 Batch:  50 Current Loss:  0.11605048179626465
# Epoch:  38 Batch:  55 Current Loss:  0.08491600304841995
# Epoch:  38 Batch:  60 Current Loss:  0.11002859473228455
# Epoch:  38 Batch:  65 Current Loss:  0.15474829077720642
# Epoch:  38 Batch:  70 Current Loss:  0.11892691999673843
# Epoch:  38 Batch:  75 Current Loss:  0.07620170712471008
# Epoch:  38 Batch:  80 Current Loss:  0.061854038387537
# ================================================================================
# Epoch 38 completed
# Average train loss is 0.10821722640710718:
# Average validation loss is 0.11449655331671238
# ================================================================================
# Epoch:  39 Batch:  0 Current Loss:  0.1827477365732193
# Epoch:  39 Batch:  5 Current Loss:  0.1471288800239563
# Epoch:  39 Batch:  10 Current Loss:  0.1397753357887268
# Epoch:  39 Batch:  15 Current Loss:  0.053563885390758514
# Epoch:  39 Batch:  20 Current Loss:  0.16976971924304962
# Epoch:  39 Batch:  25 Current Loss:  0.11431102454662323
# Epoch:  39 Batch:  30 Current Loss:  0.10892106592655182
# Epoch:  39 Batch:  35 Current Loss:  0.07188135385513306
# Epoch:  39 Batch:  40 Current Loss:  0.1257026493549347
# Epoch:  39 Batch:  45 Current Loss:  0.12800931930541992
# Epoch:  39 Batch:  50 Current Loss:  0.042395878583192825
# Epoch:  39 Batch:  55 Current Loss:  0.0612604096531868
# Epoch:  39 Batch:  60 Current Loss:  0.17472566664218903
# Epoch:  39 Batch:  65 Current Loss:  0.05118918418884277
# Epoch:  39 Batch:  70 Current Loss:  0.03982146456837654
# Epoch:  39 Batch:  75 Current Loss:  0.0935010090470314
# Epoch:  39 Batch:  80 Current Loss:  0.03963223844766617
# ================================================================================
# Epoch 39 completed
# Average train loss is 0.09715917333960533:
# Average validation loss is 0.1151040680706501
# ================================================================================
# Epoch:  40 Batch:  0 Current Loss:  0.07712188363075256
# Epoch:  40 Batch:  5 Current Loss:  0.04177459329366684
# Epoch:  40 Batch:  10 Current Loss:  0.11374108493328094
# Epoch:  40 Batch:  15 Current Loss:  0.07836838066577911
# Epoch:  40 Batch:  20 Current Loss:  0.22762739658355713
# Epoch:  40 Batch:  25 Current Loss:  0.09222278743982315
# Epoch:  40 Batch:  30 Current Loss:  0.09237661212682724
# Epoch:  40 Batch:  35 Current Loss:  0.04925909638404846
# Epoch:  40 Batch:  40 Current Loss:  0.08771932870149612
# Epoch:  40 Batch:  45 Current Loss:  0.0656663253903389
# Epoch:  40 Batch:  50 Current Loss:  0.06312350183725357
# Epoch:  40 Batch:  55 Current Loss:  0.094446562230587
# Epoch:  40 Batch:  60 Current Loss:  0.04883798211812973
# Epoch:  40 Batch:  65 Current Loss:  0.04323510825634003
# Epoch:  40 Batch:  70 Current Loss:  0.1346501111984253
# Epoch:  40 Batch:  75 Current Loss:  0.0993020310997963
# Epoch:  40 Batch:  80 Current Loss:  0.20237834751605988
# ================================================================================
# Epoch 40 completed
# Average train loss is 0.09620540672365357:
# Average validation loss is 0.20819624289870262
# ================================================================================

# %%
plt.plot(train_running_loss_history, label = 'Train Loss')
plt.plot(validation_running_loss_history, label = 'Validation Loss')
plt.legend()

# %%
model.eval()
# Out:
# UNet(
#   (inc): inconv(
#     (conv): double_conv(
#       (conv): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (down1): down(
#     (mpconv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): double_conv(
#         (conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): down(
#     (mpconv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): double_conv(
#         (conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): down(
#     (mpconv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): double_conv(
#         (conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down4): down(
#     (mpconv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): double_conv(
#         (conv): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (up1): up(
#     (up): ConvTranspose2d(512, 512, kernel_size=(2, 2), stride=(2, 2))
#     (conv): double_conv(
#       (conv): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up2): up(
#     (up): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#     (conv): double_conv(
#       (conv): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up3): up(
#     (up): ConvTranspose2d(128, 128, kernel_size=(2, 2), stride=(2, 2))
#     (conv): double_conv(
#       (conv): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up4): up(
#     (up): ConvTranspose2d(64, 64, kernel_size=(2, 2), stride=(2, 2))
#     (conv): double_conv(
#       (conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (outc): outconv(
#     (conv): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (dropout): Dropout2d(p=0.5, inplace=False)
# )

# %%
def avg_dice_index(dataloader):
    dice = 0.0
    model.eval()
    with torch.no_grad():
        for ith_batch, sample_batched in enumerate(dataloader):
            X_train = sample_batched['image'].to(device)
            y_train = sample_batched['mask'].to(device)
            y_predict = (model(X_train) + 0.5).int().float()
            dice += dice_index(y_predict, y_train)
    avg_dice = dice / len(dataloader)
    return avg_dice.item()

# %%
avg_dice_index(validation_loader)
# Out:
# /var/folders/4d/k9kg508s74x8f4h4b3sw0fsw0000gn/T/ipykernel_92553/3690571358.py:46: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   img_name = os.path.join(base_path, row[1])
# /var/folders/4d/k9kg508s74x8f4h4b3sw0fsw0000gn/T/ipykernel_92553/3690571358.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mask_name = os.path.join(base_path, row[1].replace('.jpeg', '_m.jpeg'))
# 0.8711758852005005

# %%
avg_dice_index(train_loader)
# Out:
# /var/folders/4d/k9kg508s74x8f4h4b3sw0fsw0000gn/T/ipykernel_92553/3690571358.py:46: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   img_name = os.path.join(base_path, row[1])
# /var/folders/4d/k9kg508s74x8f4h4b3sw0fsw0000gn/T/ipykernel_92553/3690571358.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mask_name = os.path.join(base_path, row[1].replace('.jpeg', '_m.jpeg'))
# 0.8026509284973145
