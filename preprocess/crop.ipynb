# %% [markdown]
# This crops all of the images and saves them into the original folder. Replace all = './clinical_data/UM'
# If you want to crop only a specific patient, replace patient_directory = './clinical_data/UM/01111517'and run # process_files(patient_directory)

# %%
import os
import cv2
import numpy as np
from PIL import Image

# %%
def crop(image):
    height, width = image.shape[:2]
    top = 100
    bottom = height - 50
    left = 30
    right = width - 150

    while top < bottom:
        row = image[top, :]
        non_black_pixels = np.count_nonzero(row)
        if non_black_pixels < 0.7 * width:
            break
        #increment the index to check the next row.
        top += 1

    while bottom > top:
        row = image[bottom, :]
        non_black_pixels = np.count_nonzero(row)
        if np.count_nonzero(row) > 0.4 * width:
            break
        bottom -= 1

    while left < right:
        column = image[:, left]
        #if the number of non-black pixels are greater than 70%
        if np.count_nonzero(column) > 0.8 * height:
            break
        left += 1

    while right > left:
        column = image[:, right]
        if np.count_nonzero(column) > 0.8 * height:
            break
        right -= 1

    return image[top:bottom+1, left:right+1]

# %%
def process_files(directory):
    print(f"Processing files in directory: {directory}")
    for filename in os.listdir(directory):
        if filename.lower().endswith(".jpg") or filename.lower().endswith(".jpeg"):
            if filename.lower().startswith("cropped_"):
                continue
            file_path = os.path.join(directory, filename)
            print(f"Processing file: {file_path}")
            try:
                image = cv2.imread(file_path)
                if image is not None:
                    cropped_image = crop(image)
                    new_file_path = os.path.join('/Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test', "c_" + filename)
                    cv2.imwrite(new_file_path, cropped_image)
                    print(f"Cropped and saved: {new_file_path}")
                else:
                    print(f"Failed to read image: {file_path}")
            except Exception as e:
                print(f"Error processing file {file_path}: {e}")

# %%
def process_all(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.jpg') or file.lower().endswith('.jpeg'):
                process_files(root)

# %%
patient_directory = '/Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM'
# all = '/Users/taliacho/Downloads/Ranger Lab/Bryan-Ranger/clinical_data/UM'
process_files(patient_directory)

# process_all(all)
# print("Script finished")
# Out:
# Processing files in directory: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_10_2024-07-24T10-38-43.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_10_2024-07-24T10-38-43.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_1_2024-07-24T10-35-30.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_1_2024-07-24T10-35-30.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_27_2024-07-24T10-40-44.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_27_2024-07-24T10-40-44.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_19_2024-07-24T10-39-29.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_19_2024-07-24T10-39-29.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_38_2024-07-24T10-44-17.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_38_2024-07-24T10-44-17.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_21_2024-07-24T10-40-11.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_21_2024-07-24T10-40-11.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_4_2024-07-24T10-37-11.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_4_2024-07-24T10-37-11.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_47_2024-07-24T10-47-04.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_47_2024-07-24T10-47-04.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_45_2024-07-24T10-46-07.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_45_2024-07-24T10-46-07.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_44_2024-07-24T10-45-11.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_44_2024-07-24T10-45-11.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_43_2024-07-24T10-45-02.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_43_2024-07-24T10-45-02.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_13_2024-07-24T10-39-01.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_13_2024-07-24T10-39-01.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_14_2024-07-24T10-39-08.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_14_2024-07-24T10-39-08.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_20_2024-07-24T10-40-09.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_20_2024-07-24T10-40-09.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_46_2024-07-24T10-47-01.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_46_2024-07-24T10-47-01.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_26_2024-07-24T10-40-27.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_26_2024-07-24T10-40-27.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_5_2024-07-24T10-37-13.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_5_2024-07-24T10-37-13.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_39_2024-07-24T10-44-18.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_39_2024-07-24T10-44-18.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_18_2024-07-24T10-39-26.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_18_2024-07-24T10-39-26.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_23_2024-07-24T10-40-21.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_23_2024-07-24T10-40-21.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_17_2024-07-24T10-39-19.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_17_2024-07-24T10-39-19.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_42_2024-07-24T10-44-51.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_42_2024-07-24T10-44-51.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_24_2024-07-24T10-40-24.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_24_2024-07-24T10-40-24.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_28_2024-07-24T10-40-45.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_28_2024-07-24T10-40-45.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_40_2024-07-24T10-44-39.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_40_2024-07-24T10-44-39.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_15_2024-07-24T10-39-10.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_15_2024-07-24T10-39-10.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_2_2024-07-24T10-35-37.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_2_2024-07-24T10-35-37.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_11_2024-07-24T10-38-46.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_11_2024-07-24T10-38-46.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_3_2024-07-24T10-35-47.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_3_2024-07-24T10-35-47.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_12_2024-07-24T10-38-54.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_12_2024-07-24T10-38-54.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_16_2024-07-24T10-39-14.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_16_2024-07-24T10-39-14.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_25_2024-07-24T10-40-25.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_25_2024-07-24T10-40-25.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_22_2024-07-24T10-40-16.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_22_2024-07-24T10-40-16.jpeg
# Processing file: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/MSK Exam - 24-Jul-2024_1030_AM/capture_41_2024-07-24T10-44-44.jpeg
# Cropped and saved: /Users/taliacho/Downloads/Ranger/Bryan-Ranger/local_data/test/c_capture_41_2024-07-24T10-44-44.jpeg
